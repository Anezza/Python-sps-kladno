# %% [markdown]
# # 1
#
# Vytvořte aplikaci, do které napíšete 5 vstupů.
# Mezi vstupy bude minimálně 1 číslo a všechen text bude o minimální délce 5 znaků. Žádný ze vstupů nesmí obsahovat kombinaci čísla a textu.   (viz cvičení na githubu: isdigit/isalpha) PS: žádný ze vstupů si nemusíte pamatovat. Stačí pouze vypsat 5 validních vstupních hodnot)

# %%
#TODO
while True:
    vstup = input("slovo nebo číslo")
    if len(str(vstup)) <= 5 :
        print("Zadejte minimálně 1 číslo nebo slovo o minimální délce 5: vstup")
    else:
        print("Zadejte jiný vstup")
        vstup = input("slovo nebo číslo")

# %% [markdown]
# **Ukázka výstupu**
# ```
# Zadejte minimálně 1 číslo nebo slovo o minimální délce 5: 5
# zadali jste: 5
# Zadejte minimálně 1 číslo nebo slovo o minimální délce 5: 7969
# zadali jste: 7969
# Zadejte minimálně 1 číslo nebo slovo o minimální délce 5: Ahojky
# zadali jste: Ahojky
# Zadejte minimálně 1 číslo nebo slovo o minimální délce 5: brrr
# Zadejte jiný vstup. Nesplnili jste žádnou z podmínek
# Zadejte minimálně 1 číslo nebo slovo o minimální délce 5: brrrrrrrrrr
# zadali jste: brrrrrrrrrr
# Zadejte minimálně 1 číslo nebo slovo o minimální délce 5: asd456
# Zadejte jiný vstup. Nesplnili jste žádnou z podmínek
# Zadejte minimálně 1 číslo nebo slovo o minimální délce 5: 45665aaaa
# Zadejte jiný vstup. Nesplnili jste žádnou z podmínek
# Zadejte minimálně 1 číslo nebo slovo o minimální délce 5: 1
# zadali jste: 1
# ```

# %% [markdown]
# # 2
#
# Vytvořte program, který se Vás zeptá na zadání jména a 5x na zadání známky. Toto se bude opakovat 3x. (3 žáci 5 známek)
# Poté vypočtěte průměr pro každého žáka a vypište ve formátu:
# „Jméno žáka“ : „průměr“

# %%
#TODO
z = 0
for i in range(3):
    jmeno = input("jmeno zaka")
    znamka1 = int(input("známka"))
    znamka2 = int(input("známka"))
    znamka3 = int(input("známka"))
    znamka4 = int(input("známka"))
    znamka5 = int(input("známka"))
    prumer = (znamka1+znamka2+znamka3+znamka4+znamka5)/5
    
    print("Zadejte jmeno:", jmeno,)
    print("zadejte znamku:", znamka1,)
    print("zadejte znamku:", znamka2,)
    print("zadejte znamku:", znamka3,)
    print("zadejte znamku:", znamka4,)
    print("zadejte znamku:", znamka5,)
    print(prumer)
print("Konec")
# Out:
# Zadejte jmeno: a
# zadejte znamku: 1
# zadejte znamku: 2
# zadejte znamku: 3
# zadejte znamku: 4
# zadejte znamku: 5
# 3.0
# Zadejte jmeno: k
# zadejte znamku: 1
# zadejte znamku: 1
# zadejte znamku: 3
# zadejte znamku: 5
# zadejte znamku: 4
# 2.8
# Zadejte jmeno: o
# zadejte znamku: 1
# zadejte znamku: 1
# zadejte znamku: 1
# zadejte znamku: 1
# zadejte znamku: 2
# 1.2
# Konec

# %% [markdown]
# **Ukázka výstupu**
#
#
# ```
# Zadejte jméno: Albert
# Zadejte známku: 1
# Zadejte známku: 2
# Zadejte známku: 3
# Zadejte známku: 4
# Zadejte známku: 5
# Albert: 3.0
# Zadejte jméno: Jindra
# Zadejte známku: 1
# Zadejte známku: 1
# Zadejte známku: 3
# Zadejte známku: 5
# Zadejte známku: 4
# Jindra: 2.8
# Zadejte jméno: Ondra
# Zadejte známku: 1
# Zadejte známku: 1
# Zadejte známku: 1
# Zadejte známku: 1
# Zadejte známku: 2
# Ondra: 1.2
# Konec
# ```

# %% [markdown]
# # 3
#
# Vytvoř program, který požádá uživatele o zadání počtu bodů (0 - 100).
#
# Na základě počtu bodů program přiřadí známku podle těchto pravidel:
# * 90 až 100 bodů: "Výborně (1)"
# * 75 až 89 bodů: "Chvalitebně (2)"
# * 60 až 74 bodů: "Dobře (3)"
# * 50 až 59 bodů: "Dostatečně (4)"
# * 0 až 49 bodů: "Nedostatečně (5)"
#
# Pokud uživatel zadá číslo mimo rozsah 0-100, program vypíše chybovou hlášku: "Neplatný počet bodů."

# %%
#TODO
x = int(input("pocet bodu"))
print("Zadej počet bodů: ", x)
if x > 100:
    print("Neplatný počet bodů.")
elif x < 0:
    print("Neplatný počet bodů.")
elif x > 90:
    print("Výborně (1)")
elif x >75 < 89 :
    print("Chvalitebně (2)")
elif x >60 <74:
    print("Dobře (3)")
elif x >50 <59:
    print("Dostatečně (4)")
elif x >0 <49:
    print("Nedostatečně (5)")
# Out:
# Zadej počet bodů:  5
# Nedostatečně (5)

# %% [markdown]
# **Ukázka řešení**
#
#
# ```
# Zadej počet bodů (0-100): 5
# Známka: Nedostatečně (5)
# ```
# Nebo
#
#
# ```
# Zadej počet bodů (0-100): 73
# Známka: Dobře (3)
# ```

# %% [markdown]
# # 4
# Vytvoř program, který požádá uživatele o zadání jeho celého jména
# Program vypíše:
# * Počet znaků ve jménu (bez mezer).
# * První písmeno křestního jména a první písmeno příjmení (velkým písmem).
# * Celé jméno převrácené (např. "Novák Jan" se stane "naJ kávon").
#
# Pokud jméno obsahuje méně než dvě slova (křestní jméno a příjmení), program vypíše varování: "Zadejte své celé jméno (křestní jméno a příjmení)."

# %%
#TODO
jmeno = input("cele jmeno")
if " " not in jmeno:
    print("zadejte sve cele jmeno")
    jmeno = input("cele jmeno")
rozd = jmeno.split(" ")
jm = rozd[0]
pr = rozd[1]
index = 0
print("Zadej své celé jméno:", jmeno)
znak = len(jmeno)
print("Počet znaků:", znak)
print("iniciály:", jm[index].upper(), pr[index].upper())
print("Převrácené jméno:", jmeno[::-1])
# Out:
# zadejte sve cele jmeno
# Zadej své celé jméno: Jan Novák
# Počet znaků: 9
# iniciály: J N
# Převrácené jméno: kávoN naJ

# %% [markdown]
# **Ukázka kódu**
#
# ```
# Zadej své celé jméno: Jan Novák
# Počet znaků (bez mezer): 8
# Iniciály: J N
# Převrácené jméno: kávoN naJ
# ```
