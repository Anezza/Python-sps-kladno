# %% [markdown]
# #1. Zadání
#
# Vytvořte třídu Člověk, která bude mít atributy:
#
#
# 1.   jméno:str
# 2.   příjmení:str
# 3.   telefon:int
# 4.   email:str
# 5. adresa:str
# 6. pojišťovna:str
#
# Vytvořte metody, které budou moc získávat a měnit tyto atributy. Také vytvořte metodu, která vám vypíše vše o této osobě

# %%
class Clovek:
    def __init__(self,jmeno,prijmeni,telefon,email,adresa,pojistovna):
        self.jmeno = jmeno
        self.prijmeni = prijmeni
        self.telefon = telefon
        self.email = email
        self. adresa = adresa
        self.pojistovna = pojistovna
        #self.vek = 0
    def get_jmeno(self):
        return self.jmeno
    def set_jmeno(self, novejmeno):
        self.jmeno = novejmeno
        print("Jméno bylo změněno")

    def get_prijmeni(self):
        return self.prijmeni
    def set_prijmeni(self,noveprijmeni):
        self.prijmeni = noveprijmeni
        print("Příjmení bylo změněno")

    def get_telefon(self):
        return self.telefon
    def set_telefon(self, novytelefon):
        self.telefon = novytelefon
        print("Telefon byl změněn")

    def get_email(self):
        return self.email
    def set_email(self, novyemail):
        self.email = novyemail
        print("Email byl změněn")

    def get_adresa(self):
        return self.adresa
    def set_adresa(self, novaadresa):
        self.adresa = novaadresa
        print("Adresa byla změněna")

    def get_pojistovna(self):
        return self.pojistovna
    def set_pojistovna(self, novapojistovna):
        self.pojistovna = novapojistovna
        print("Pojišťovna byla změněna")
        
    def __str__(self):#ToString -> vypise vsechny informace o tride ve stringu
        return f"""
Jméno: {self.jmeno} 
Příjmení: {self.prijmeni}
Telefon: {self.telefon} 
Email: {self.email}
Adresa: {self.adresa} 
Pojišťovna: {self.pojistovna}
"""
    
clovek1 = Clovek("Aneta", "Veselá", 1546, "aneta@spskladno.cz", "Jahodová 12", "VZP")
clovek2 = Clovek("bfbhjt", "GRNJU", 46, "an@spskladno.cz", "Jahodová 1", "VZDR")
print(clovek1)
clovek1.set_prijmeni("Nesmysl")
print(clovek1)
print(clovek2.get_jmeno())
# Out:
# Jméno: Aneta
# Příjmení: Veselá
# Telefon: 1546
# Email: aneta@spskladno.cz
# Adresa: Jahodová 12
# Pojišťovna: VZP
#
# Příjmení bylo změněno
#
# Jméno: Aneta
# Příjmení: Nesmysl
# Telefon: 1546
# Email: aneta@spskladno.cz
# Adresa: Jahodová 12
# Pojišťovna: VZP
#
# bfbhjt

# %%
# Out:
# aneta
# Jméno změněno.
# Karel
#
# Jméno: Karel
# Prijmeni: a
# Telefon: 456
# Email: ah@as.cz
# Adresa: VZP
# Pojistovna: VZP
# Mesto: Kladno

# %% [markdown]
# #2. Zadání
#
# upravte třídu Člověk tak, abyste ošetřili následující atributy:
#
#
# 1.   jméno:str
# 2.   příjmení:str
# 3.   telefon:int (maximálně 9 znaků)
# 4.   email:str (musí obsahovat @)
# 5. adresa:str
# 6. pojišťovna:str
#
# Upravte metody, které budou moc měnit tyto atributy i s aplikovanými omezeními.

# %%
  #TODO
class Clovek:
    def __init__(self,jmeno,prijmeni,telefon,email,adresa,pojistovna):
        self.jmeno = jmeno
        self.prijmeni = prijmeni
        self.telefon = telefon
        self.email = email
        self. adresa = adresa
        self.pojistovna = pojistovna
        #self.vek = 0
        if "@" in email:
            self.email = email
        else:
            print("Email, který jste zadali je neplatný")
            self.email = ""
        self.adresa = adresa
        self.pojistovna = pojistovna
    def setTelefon(self,telefon):
        if len(str(telefon)) == 9:
            self.telefon = telefon
        else:
            print("Telefon, který jste zadali je neplatný")
            self.telefon = ""
    def getEmail(self):
        return self.email
    def setEmail(self,email):
        if "@" in email:
            self.email = email
        else:
            print("Email, který jste zadali je neplatný")
            self.email = ""
            
    def get_jmeno(self):
        return self.jmeno
    def set_jmeno(self, novejmeno):
        self.jmeno = novejmeno
        print("Jméno bylo změněno")

    def get_prijmeni(self):
        return self.prijmeni
    def set_prijmeni(self,noveprijmeni):
        self.prijmeni = noveprijmeni
        print("Příjmení bylo změněno")

    def get_telefon(self):
        return self.telefon
    def set_telefon(self, telefon):
        if telefon <100000000 or telefon > 999999999
          print("Neplatné")
          self.telefon = 1
        self.telefon = telefon
        print("Telefon byl změněn")

    def get_email(self):
        return self.email
    def set_email(self, novyemail):
        self.email = novyemail
        print("Email byl změněn")
        if 

    def get_adresa(self):
        return self.adresa
    def set_adresa(self, novaadresa):
        self.adresa = novaadresa
        print("Adresa byla změněna")
        if @

    def get_pojistovna(self):
        return self.pojistovna
    def set_pojistovna(self, novapojistovna):
        self.pojistovna = novapojistovna
        print("Pojišťovna byla změněna")
        
    def __str__(self):#ToString -> vypise vsechny informace o tride ve stringu
        return f"""
Jméno: {self.jmeno} 
Příjmení: {self.prijmeni}
Telefon: {self.telefon} 
Email: {self.email}
Adresa: {self.adresa} 
Pojišťovna: {self.pojistovna}
"""
    
clovek1 = Clovek("Aneta", "Veselá", 1546, "aneta@spskladno.cz", "Jahodová 12", "VZP")
clovek2 = Clovek("bfbhjt", "GRNJU", 46, "an@spskladno.cz", "Jahodová 1", "VZDR")
print(clovek1)
clovek1.set_prijmeni("Nesmysl")
print(clovek1)
print(clovek2.get_jmeno())

# %%
#Zde vytvořte alespoň 2 lidi a zkuste si všechny metody na jedné z nich

# %% [markdown]
# #3. Zadání
#
# Vytvořte třídu pojištovna, která bude mít atributy:
#
#
# 1.   název:str
# 2.   zkratkaPojištovny:str (maximálně 3 znaky)
# 3. sídlo:str
#
# Vytvořte metody, které budou moc získávat a měnit tyto atributy. Také vytvořte metodu, která vám vypíše vše o této pojišťovně.

# %%
class Pojistovna:
  #TODO
  def __init__(self, nazev, zkratka, sidlo):
    self.nazev = nazev
    self.sidlo = sidlo 
    if len(str(zkratka)) <= 3:
      self.zkratka = zkratka
    else:
      self.zkratka = zkratka [:3]

  def get_nazev(self):
    return self.nazev
  def set_nazev(self, novynazev):
    self.nazev = novynazev
    print("Název byl změněn")
    
  def get_zkratka(self):
    return self.zkratka
  def set_zkratka(self, novazkratka):
    if len(str(novazkratka)) <= 3:
      self.zkratka = novazkratka
    else:
      self.zkratka = novazkratka [:3]
    print("Zkratka byla změněna")

  def get_sidlo(self):
    return self.sidlo
  def set_sidlo(self, novesidlo):
    self.sidlo = novesidlo
    print("Sídlo bylo změněno")

  def __str__(self):
    return f"""
Název: {self.nazev}
Zkratka: {self.zkratka}
Sídlo: {self.sidlo}
"""

# %%
pojistovna1= Pojistovna("aewgt", "VZP", "56874")
pojistovna2= Pojistovna("tzui", "VZP", "45287")
# Out:
# Něj

# %% [markdown]
# #4. Zadání
#
# Upravte třídu Člověk tak, aby atribut pojišťovna byl vložen jako třída Pojišťovna
#
#
# 1.   jméno:str
# 2.   příjmení:str
# 3.   telefon:int (maximálně 9 znaků)
# 4.   email:str (musí obsahovat @)
# 5. adresa:str
# 6. pojišťovna:class(Pojišťovna)
#
# Upravte metodu, která vám vypíše vše o této osobě tak, aby Vám také vypsala všechny informace o dané pojišťovně

# %%
class Clovek:
  #TODO

# %%
#Zde vytvořte alespoň 2 lidi a zkuste si všechny metody na jedné z nich
print(karel)

# %% [markdown]
# Ukázka Výstupu:
# ```
# Telefon, který jste zadali je neplatný
# Email, který jste zadali je neplatný
#
#         Jméno: Karel
#         Příjmení: Hympa
#         Telefon:
#         Email:
#         Adresa: Svatojánská 36
#         Pojišťovna: VZP
#
#
#         Jméno: Jarda
#         Příjmení: Klomajz
#         Telefon: 987654321
#         Email: Jarda@seznam.cz
#         Adresa: Svatojánská 37
#         Pojišťovna:
#         Název: Všeobecná pojišťovna
#         Zkratka: VZP
#         Sídlo: Armádní 93
# ```

# %% [markdown]
# # Počasí
#
# Vytvořte třídu Pocasi, která bude mít atributy:
#
# 1.   vítr:float
# 2.   povetrnostniPodminky:str
# 3.   teplota:float
# 4.   vlhkost:float
#
# Vytvořte metody, které budou moc získávat a měnit tyto atributy. Také vytvořte metodu, která vám vypíše vše tomto počasí

# %%
class Pocasi:
    #TODO
    def __init__(self, vitr, podminky, teplota, vlhkost):
        self.vitr = vitr
        self.podminky = podminky
        self.teplota = teplota
        self.vlhkost = vlhkost

    def get_vitr(self):
        return self.vitr
    def set_vitr(self, vitr):
        self.vitr = vitr
        print("Vítr byl změněn")

    def get_podminky(self):
        return self.podminky
    def set_podminky(self, podminky):
        self.podminky = podminky
        print("Povětrnostní podmínky byly změněny")

    def get_teplota(self):
        return self.teplota
    def set_teplota(self, teplota):
        self.teplota = teplota
        print("Teplota byla změněna")

    def get_vlhkost(self):
        return self.vlhkost
    def set_vlhkost(self, vlhkost):
        self.vlhkost = vlhkost
        print("Vlhkost byla změněna")

    def __str__(self):
        return f"""
Vítr: {self.vitr}
Povětrnostní podmínky: {self.podminky}
Teplota: {self.teplota}
Vlhkost: {self.vlhkost}
"""

# %%
#Zde vytvořte alespoň 2 záznamy počasí a zkuste si všechny metody na jedné z nich

# %% [markdown]
# Ukázka Výstupu:
#
# ```
# Rychlost větru: 17 km/h
# Teplota: 18 °C
# Vlhost vzduchu: 54 %
# Počasí: Zataženo
# ```

# %% [markdown]
# # Počasí
# Upravte třídu Pocasi, aby přijímala Enum (na výběr z: Slunečno, zataženo, bouřky atd.)

# %%
from enum import Enum
class Pocasicko(Enum):

class Pocasi:
    #TODO
    def __init__(self, vitr, podminky, teplota, vlhkost):
        self.vitr = vitr
        self.podminky = podminky
        self.teplota = teplota
        self.vlhkost = vlhkost

    def get_vitr(self):
        return self.vitr
    def set_vitr(self, vitr):
        self.vitr = vitr
        print("Vítr byl změněn")

    def get_podminky(self):
        return self.podminky
    def set_podminky(self, podminky):
        self.podminky = podminky
        print("Povětrnostní podmínky byly změněny")

    def get_teplota(self):
        return self.teplota
    def set_teplota(self, teplota):
        self.teplota = teplota
        print("Teplota byla změněna")

    def get_vlhkost(self):
        return self.vlhkost
    def set_vlhkost(self, vlhkost):
        self.vlhkost = vlhkost
        print("Vlhkost byla změněna")

    def __str__(self):
        return f"""
Vítr: {self.vitr}
Povětrnostní podmínky: {self.podminky}
Teplota: {self.teplota}
Vlhkost: {self.vlhkost}
"""

# %%
p1 = Pocasi(31,Pocasicko.SLUNECNO.value,25,14)
print(p1)
p1.setpodminky(Pocasicko.ZATAZENO.value)
print(p1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 p1 = Pocasi(31,Pocasicko.SLUNECNO.value,25,14)
#       2 print(p1)
#       3 p1.setpodminky(Pocasicko.ZATAZENO.value)
#
# NameError: name 'Pocasi' is not defined
