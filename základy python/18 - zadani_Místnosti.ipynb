# %% [markdown]
# **Vytvořte Třídu Room, která bude obsahovat atributy:**
#
#
# 1. název
# 2. seznamExitu
# 3. poklad
# 4. nepritel
#
# **Vytvořte metody:**
#
#
# 1.   addExit, getNazev, getExity, getPoklad, getNepritel, toString
# 2.   setNazev

# %%
#TODO
class Room:
    def __init__(self, nazev):
        self.nazev= nazev
        self.seznamExitu = []
        self.poklad = []
        self.nepritel = []

    def getNazev(self):
        return self.nazev
    
    def getExity(self):
        return self.seznamExitu
    
    def getPoklad(self):
        return self.poklad

    def getNepritel(self):
        return self.nepritel
    
    def __str__(self):
        if self.poklad is not None:
            if self.nepritel is not None:
                return f"Jsi v místnosti {self.nazev} a vidíš poklad {self.poklad} a nepřítele {self.nepritel}"
            else:
                return f"Jsi v místnosti {self.nazev} a vidíš poklad {self.poklad}"
        elif self.nepritel is not None:
            return f"Jsi v místnosti {self.nazev} a vidíš nepřítele {self.nepritel}"
        else:
            return f"Jsi v místnosti {self.nazev} a jsi tu sám" 
    
    def setNazev(self,nazev):
        self.nazev = nazev

    def addExit(self,exit_room):
        self.seznamExitu.append(exit_room)

    def getSeznamExitu(self):
        text = ""
        for exit in self

# %% [markdown]
# **Zde je vytvořená jednoduchá mapa s výpisy**

# %%
room1 = Room("Vstup do jeskyně")
room2 = Room("Jezírko")
room3 = Room("Předsíň draka")
room4 = Room("Dračí slůj")
room5 = Room("Vyhlídka")

room1.addExit(room5)
room5.addExit(room1)
room1.addExit(room2)
room1.addExit(room4)
room2.addExit(room1)
room4.addExit(room1)
room4.addExit(room3)
room4.addExit(room5)
room3.addExit(room4)
room5.addExit(room4)

aktualni = room1
print(aktualni.getSeznamExitu())
print(aktualni.getNepritel())
print(aktualni.getPoklad())
print(aktualni)

#chci se přesunout tak si změním aktualní na jeden z východu
aktualni = aktualni.seznamExitu[0]
print(aktualni)
#aktualni = aktualni.seznamExitu[2] # již nemá 3 exit --> skončí chybou
#print(aktualni)
aktualni = aktualni.seznamExitu[1]
print(aktualni)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 7
#       4 room4 = Room("Dračí slůj")
#       5 room5 = Room("Vyhlídka")
# ----> 7 room1.addExit(room5)
#       8 room5.addExit(room1)
#       9 room1.addExit(room2)
#
# AttributeError: 'Room' object has no attribute 'addExit'
